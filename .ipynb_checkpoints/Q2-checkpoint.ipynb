# %% [markdown]
# # Question Q2

# %% [markdown]
# *Question*: Based on your experience, what activities do you consider to be most difficult when defining requirements for ML-enabled systems?

# %% [markdown]
# *Answer Type*: Multiple Single Option

# %% [markdown]
# *Options*: [Very Easy, Easy, Neutral, Complex, Very Complex, I don't know]

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Init

# %%
dataframe_obj = DataframeUtils('./data/main_data.csv', ';', './data/unused_columns.txt', './data/formatted_columns.txt')
# the index is not important, but when we internally format df we need to reset index
dataframe_obj.df = dataframe_obj.df.reset_index(drop=True)

# %%
ml_stages = {
    'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding': 'Problem Understanding',
    'Q2_ML_Life_Cycle_Difficulty_Data_Collection': 'Data Collection',
    'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing': 'Data Pre-Processing',
    'Q2_ML_Life_Cycle_Difficulty_Model_Creation': 'Model Creation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation': 'Model Evaluation',
    'Q2_ML_Life_Cycle_Difficulty_Model_Deployment': 'Model Deployment',
    'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring': 'Model Monitoring'
}

# %% [markdown]
# ### Basic Analysis

# %%
dataframe_obj.df[['Q2_ML_Life_Cycle_Difficulty_Problem_Understanding', 'Q2_ML_Life_Cycle_Difficulty_Data_Collection',
'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing', 'Q2_ML_Life_Cycle_Difficulty_Model_Creation',
'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation', 'Q2_ML_Life_Cycle_Difficulty_Model_Deployment',
'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring']].head()
# Out:
#   Q2_ML_Life_Cycle_Difficulty_Problem_Understanding  \
# 0                                                 0
# 1                                           Complex
# 2                                           Complex
# 3                                           Complex
# 4                                           Neutral
#
#   Q2_ML_Life_Cycle_Difficulty_Data_Collection  \
# 0                                           0
# 1                                     Complex
# 2                                Very Complex
# 3                                        Easy
# 4                                     Neutral
#
#   Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing  \
# 0                                               0
# 1                                    Very Complex
# 2                                         Complex
# 3                                            Easy
# 4                                         Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Creation  \
# 0                                          0
# 1                               Very Complex
# 2                                    Complex
# 3                                    Neutral
# 4                                    Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Evaluation  \
# 0                                            0
# 1                                      Complex
# 2                                      Neutral
# 3                                      Complex
# 4                                 Very Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Deployment  \
# 0                                            0
# 1                                 Very Complex
# 2                                      Neutral
# 3                                 Very Complex
# 4                                 Very Complex
#
#   Q2_ML_Life_Cycle_Difficulty_Model_Monitoring
# 0                                            0
# 1                                      Neutral
# 2                                      Complex
# 3                                         Easy
# 4                                      Neutral

# %%
# cleaning data in all Q2 columns

# replace two 'not checked' values (0 and -77) to "I don't know" value

dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Problem_Understanding', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Data_Collection', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Data_Pre-Processing', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Model_Creation', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Model_Evaluation', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Model_Deployment', ["0", "-77"], "I don't know", "eq")
dataframe_obj.replace_list_values_by_condition(
    'Q2_ML_Life_Cycle_Difficulty_Model_Monitoring', ["0", "-77"], "I don't know", "eq")

# %%
# each ML stage has a different distribution of answers
for ml_stage in ml_stages:
    # barplot data
    indexes = list(dataframe_obj.df[ml_stage].value_counts().index)
    values = list(dataframe_obj.df[ml_stage].value_counts())
    
    # plot object
    q2_plot = PlotUtils(pd.DataFrame(
        data={'Difficulty': indexes, 'Answers': values}
    ))
    
    q2_plot.single_barplot(x_axis="Answers", y_axis="Difficulty", 
                           title=ml_stages[ml_stage] + "\n How difficult do you think each of the seven ML life cycle stages are in general?",
                           x_label="Valid Answers", y_label="Difficulty", x_label_rotation=0)

# %% [markdown]
# ### Bootstrapping Analysis

# %%
# each ML stage has a different distribution of answers in bootstrapping
for ml_stage in ml_stages:
    valid_options_list = list(dataframe_obj.df[ml_stage].unique())
    valid_answers_list = list(dataframe_obj.df[ml_stage])
    
    bootstrapping_obj = BootstrappingUtils(valid_answers_list, valid_options_list, 1000, 1000, 0.95)
    
    bootstrapped_dict_data = bootstrapping_obj.bootstrapping()
    
    # get a pair of values between dict key and all the list values inside that key 
    # key: [val_1, val_2] ---> [(key, val_1), (key, val_2)...]
    indexes = []
    values = []
    for idx in bootstrapped_dict_data:
        indexes += [idx for _ in range(len(bootstrapped_dict_data[idx]['population']))]
        values += bootstrapped_dict_data[idx]['population']
        
    # plot object for bootstrapped data
    q2_boot_plot = PlotUtils(pd.DataFrame(
        data={'Difficulty': indexes, 'Value': values}
    ).sort_values(by=['Value'], ascending=False))
    
    q2_boot_plot.single_barplot(x_axis="Value", y_axis="Difficulty", 
                                title=ml_stages[ml_stage] + " - Bootstrapping - 95% confidence \n How difficult do you think each of the seven ML life cycle stages are in general?",
                                x_label="Percentage of Answers", y_label="Difficulty", x_label_rotation=0)
    
    # confidence for each option
    print("Option " + ml_stages[ml_stage] + ": (Lower Value, Mean, Upper Value)")
    for idx in bootstrapped_dict_data:
        print(idx + ':' + str(bootstrapped_dict_data[idx]['confidence']))
    
    print(20*"---")
# Out:
# Option Problem Understanding: (Lower Value, Mean, Upper Value)
# I don't know:(33.68753888155616, 33.7318, 33.77606111844384)
# Complex:(29.30661983149087, 29.3497, 29.392780168509127)
# Neutral:(15.24364176002184, 15.2785, 15.31335823997816)
# Very Complex:(18.37915146054455, 18.416, 18.452848539455452)
# Easy:(2.857787813186488, 2.8734, 2.8890121868135124)
# Very Easy:(0.345326033267075, 0.3506, 0.35587396673292504)
# ------------------------------------------------------------
# Option Data Collection: (Lower Value, Mean, Upper Value)
# I don't know:(33.65143650774417, 33.695100000000004, 33.738763492255835)
# Complex:(21.68093726606149, 21.7196, 21.75826273393851)
# Very Complex:(14.850402535174814, 14.8848, 14.919197464825187)
# Easy:(6.870152304894231, 6.8942, 6.9182476951057685)
# Neutral:(22.768028199614143, 22.8063, 22.844571800385857)
# ------------------------------------------------------------
# Option Data Pre-Processing: (Lower Value, Mean, Upper Value)
# I don't know:(34.042786640073764, 34.0883, 34.13381335992623)
# Very Complex:(12.692768565244242, 12.7259, 12.759031434755757)
# Complex:(26.346065548046944, 26.3883, 26.430534451953058)
# Easy:(6.115905448608241, 6.1394, 6.1628945513917595)
# Neutral:(20.262426322586208, 20.3007, 20.33897367741379)
# Very Easy:(0.3517043368164892, 0.3574, 0.3630956631835108)
# ------------------------------------------------------------
# Option Model Creation: (Lower Value, Mean, Upper Value)
# I don't know:(33.34221751577759, 33.387100000000004, 33.43198248422242)
# Very Complex:(8.703338749433698, 8.7288, 8.754261250566302)
# Complex:(24.55381744281591, 24.5944, 24.63498255718409)
# Neutral:(22.069597015107444, 22.1092, 22.14880298489256)
# Easy:(9.712948074246276, 9.742, 9.771051925753726)
# Very Easy:(1.42677268383751, 1.4385000000000001, 1.4502273161624901)
# ------------------------------------------------------------
# Option Model Evaluation: (Lower Value, Mean, Upper Value)
# I don't know:(33.97472911078742, 34.0183, 34.061870889212585)
# Complex:(26.443258498024264, 26.4848, 26.526341501975736)
# Neutral:(20.604317722268185, 20.6429, 20.681482277731817)
# Very Complex:(9.403506747236824, 9.431000000000001, 9.458493252763178)
# Easy:(9.025435132382727, 9.0535, 9.081564867617272)
# Very Easy:(0.3635947164018144, 0.3695, 0.3754052835981856)
# ------------------------------------------------------------
# Option Model Deployment: (Lower Value, Mean, Upper Value)
# I don't know:(35.05574514415155, 35.102199999999996, 35.14865485584844)
# Very Complex:(10.81721554270433, 10.8473, 10.87738445729567)
# Neutral:(25.489686084802553, 25.5314, 25.57311391519745)
# Complex:(22.71347054840774, 22.752, 22.790529451592256)
# Easy:(5.0312251095282186, 5.0527, 5.074174890471781)
# Very Easy:(0.7064714750678326, 0.7144, 0.7223285249321675)
# ------------------------------------------------------------
# Option Model Monitoring: (Lower Value, Mean, Upper Value)
# I don't know:(35.7497932267592, 35.7961, 35.8424067732408)
# Neutral:(29.013446981088634, 29.0564, 29.099353018911366)
# Complex:(20.685935763949022, 20.7243, 20.762664236050977)
# Easy:(8.259400171620808, 8.2857, 8.311999828379193)
# Very Complex:(5.389802457748598, 5.4110000000000005, 5.432197542251403)
# Very Easy:(0.7184699567638151, 0.7265, 0.734530043236185)
# ------------------------------------------------------------
