# %% [markdown]
# # Question Q3

# %% [markdown]
# *Question*: How much percentage of effort do you think is spent in each of the seven ML life cycle stages?

# %% [markdown]
# *Answer Type*: Multiple Numerical

# %% [markdown]
# ### Necessary Libraries

# %%
import pandas as pd
from utils.basic import rename_values
from utils.dataframe import DataframeUtils
from utils.plot import PlotUtils
from utils.bootstrapping import BootstrappingUtils

# %% [markdown]
# ### Dataframe Init

# %%
dataframe_obj = DataframeUtils('./data/main_data.csv', ';', './data/unused_columns.txt', './data/formatted_columns.txt')
# the index is not important, but when we internally format df we need to reset index
dataframe_obj.df = dataframe_obj.df.reset_index(drop=True)

# %%
ml_stages = {
    'Q3_ML_Life_Cycle_Effort_Problem_Understanding': 'Problem Understanding',
    'Q3_ML_Life_Cycle_Effort_Data_Collection': 'Data Collection',
    'Q3_ML_Life_Cycle_Effort_Data_Pre-Processing': 'Data Pre-Processing',
    'Q3_ML_Life_Cycle_Effort_Model_Creation': 'Model Creation',
    'Q3_ML_Life_Cycle_Effort_Model_Evaluation': 'Model Evaluation',
    'Q3_ML_Life_Cycle_Effort_Model_Deployment': 'Model Deployment',
    'Q3_ML_Life_Cycle_Effort_Model_Monitoring': 'Model Monitoring'
}

# %% [markdown]
# ### Basic Analysis

# %%
dataframe_obj.df[['Q3_ML_Life_Cycle_Effort_Problem_Understanding', 'Q3_ML_Life_Cycle_Effort_Data_Collection',
'Q3_ML_Life_Cycle_Effort_Data_Pre-Processing', 'Q3_ML_Life_Cycle_Effort_Model_Creation', 
'Q3_ML_Life_Cycle_Effort_Model_Evaluation', 'Q3_ML_Life_Cycle_Effort_Model_Deployment',
'Q3_ML_Life_Cycle_Effort_Model_Monitoring']].head()
# Out:
#   Q3_ML_Life_Cycle_Effort_Problem_Understanding  \
# 0                                             5
# 1                                            30
# 2                                            20
# 3                                            30
# 4                                            15
#
#   Q3_ML_Life_Cycle_Effort_Data_Collection  \
# 0                                      20
# 1                                      12
# 2                                      10
# 3                                      10
# 4                                      10
#
#   Q3_ML_Life_Cycle_Effort_Data_Pre-Processing  \
# 0                                          30
# 1                                          12
# 2                                          15
# 3                                          10
# 4                                          10
#
#   Q3_ML_Life_Cycle_Effort_Model_Creation  \
# 0                                     25
# 1                                     12
# ...

# %%
# cleaning data in all Q3 columns
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Problem_Understanding', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Data_Collection', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Data_Pre-Processing', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Model_Creation', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Model_Evaluation', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Model_Deployment', "-66", "0", "eq")
dataframe_obj.replace_value_by_condition(
    'Q3_ML_Life_Cycle_Effort_Model_Monitoring', "-66", "0", "eq")

# %%
# convert column to integer - if you read before this line, you will get an string like '14'
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Problem_Understanding": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Data_Collection": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Data_Pre-Processing": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Model_Creation": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Model_Evaluation": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Model_Deployment": int}, errors='raise') 
dataframe_obj.df = dataframe_obj.df.astype({"Q3_ML_Life_Cycle_Effort_Model_Monitoring": int}, errors='raise')

# %% [markdown]
# #### Problem Understanding

# %%
# each ML stage has a different distribution of answers
q3_plot_understanding = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding']))

q3_plot_understanding.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                   total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding']))

q3_plot_understanding.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                   total_answers=total_answers)

# %%
q3_plot_understanding.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_understanding.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Data Collection

# %%
# each ML stage has a different distribution of answers
q3_plot_collection = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection']))

q3_plot_collection.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection']))

q3_plot_collection.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
q3_plot_collection.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_collection.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Data Pre-Processing

# %%
# each ML stage has a different distribution of answers
q3_plot_processing = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing']))

q3_plot_processing.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing']))

q3_plot_processing.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
q3_plot_processing.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_processing.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Model Creation

# %%
# each ML stage has a different distribution of answers
q3_plot_creation = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation']))

q3_plot_creation.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation']))

q3_plot_creation.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                total_answers=total_answers)

# %%
q3_plot_creation.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_creation.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Model Evaluation

# %%
# each ML stage has a different distribution of answers
q3_plot_evaluation = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation']))

q3_plot_evaluation.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation']))

q3_plot_evaluation.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
q3_plot_evaluation.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_evaluation.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Model Deployment

# %%
# each ML stage has a different distribution of answers
q3_plot_deployment = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment']))

q3_plot_deployment.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment']))

q3_plot_deployment.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                                  total_answers=total_answers)

# %%
q3_plot_deployment.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_deployment.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# #### Model Monitoring

# %%
# each ML stage has a different distribution of answers
q3_plot_monitoring = PlotUtils(pd.DataFrame(
    data={'Effort': list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring'])}
))

# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring']))

q3_plot_monitoring.single_boxplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                   total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring']))

q3_plot_monitoring.single_boxplot("Effort", outliers=False,
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                   total_answers=total_answers)

# %%
q3_plot_monitoring.single_violinplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_plot_monitoring.single_histplot("Effort",
                   title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + "\nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %% [markdown]
# ### Bootstrapping Analysis

# %% [markdown]
# #### Problem Understanding

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_understanding_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding']))

q3_understanding_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Problem_Understanding']))

q3_understanding_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_understanding_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_understanding_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Problem_Understanding'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (12.134519890247816, 14.054347826086957, 15.974175761926098)

# %% [markdown]
# #### Data Collection

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_collection_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection']))

q3_collection_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Collection']))

q3_collection_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_collection_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_collection_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Collection'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (9.873143835447312, 11.083333333333334, 12.293522831219356)

# %% [markdown]
# #### Data Pre-Processing

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_processing_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing']))

q3_processing_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing']))

q3_processing_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_processing_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_processing_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Data_Pre-Processing'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (11.157023860110632, 12.684782608695652, 14.212541357280672)

# %% [markdown]
# #### Model Creation

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_creation_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation']))

q3_creation_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Creation']))

q3_creation_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_creation_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_creation_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Creation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (9.799453843665383, 11.115942028985508, 12.432430214305633)

# %% [markdown]
# #### Model Evaluation

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_evaluation_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation']))

q3_evaluation_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Evaluation']))

q3_evaluation_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_evaluation_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_evaluation_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Evaluation'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (6.692988651551167, 7.481884057971015, 8.270779464390861)

# %% [markdown]
# #### Model Deployment

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_deployment_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment']))

q3_deployment_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Deployment']))

q3_deployment_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_deployment_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_deployment_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Deployment'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (6.085156636146068, 6.934782608695652, 7.784408581245237)

# %% [markdown]
# #### Model Monitoring

# %%
# each ML stage has a different distribution of answers
valid_answers_list = list(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring'])

total_answers_int = len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring'])

# %%
replacements = 1000
population_sample_size = total_answers_int # equals n - total valid answers

bootstrapping_obj = BootstrappingUtils(valid_answers_list, [], replacements, population_sample_size, 95)

# %%
bootstrapped_list_data = bootstrapping_obj.bootstrapping_numerical_fields()

# %%
# plot object for bootstrapped data
q3_monitoring_boot_plot = PlotUtils(pd.DataFrame(
    data={'Effort': bootstrapped_list_data['population']}
))

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring']))

q3_monitoring_boot_plot.single_boxplot("Effort",
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
# compute total of answer considered in this question
total_answers = "N = " + str(len(dataframe_obj.df['Q3_ML_Life_Cycle_Effort_Model_Monitoring']))

q3_monitoring_boot_plot.single_boxplot("Effort", outliers=False,
                            title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?",
                            total_answers=total_answers)

# %%
q3_monitoring_boot_plot.single_violinplot("Effort",
                               title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
q3_monitoring_boot_plot.single_histplot("Effort",
                             title=ml_stages['Q3_ML_Life_Cycle_Effort_Model_Monitoring'] + " - Bootstrapping - 95% confidence \nHow much percentage of effort do you think is spent in each of the seven ML life cycle stages?")

# %%
# confidence for each option
print("Option: (Lower Value, Mean, Upper Value)")
print(bootstrapped_list_data['confidence'])
# Out:
# Option: (Lower Value, Mean, Upper Value)
# (4.541358045752579, 5.094202898550725, 5.64704775134887)
